# %%
# %%writefile log_streaming.py
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# SparkContext con 2 hilos mínimo para Streaming
sc = SparkContext("local[2]", "LogErrorMonitor")

# Batch interval de 5 segundos (puedes ajustar)
ssc = StreamingContext(sc, 5)

# Escuchar la carpeta "logs" (debe existir)
log_dir = "logs"

# Cada nuevo archivo que aparezca en logs/ será procesado
lines = ssc.textFileStream(log_dir)

# Filtrar solo líneas con ERROR y sin WARNING
errors = lines.filter(lambda line: ("ERROR" in line) and ("WARNING" not in line))

# Mostrar en consola
errors.pprint()

print(f"Escuchando logs en: {log_dir}")
print("Solo se mostrarán líneas con ERROR (sin WARNING).")

ssc.start()
ssc.awaitTermination()
# Out:
# Writing log_streaming.py

# %%
#!spark-submit log_streaming.py
# !streamlit run log_streaming.py --server.port 8501 --server.address 0.0.0.0
# Out:
# 25/11/20 23:18:05 INFO SparkContext: Running Spark version 3.5.1
# 25/11/20 23:18:05 INFO SparkContext: OS info Linux, 5.15.167.4-microsoft-standard-WSL2, amd64
# 25/11/20 23:18:05 INFO SparkContext: Java version 17.0.17-internal
# 25/11/20 23:18:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/20 23:18:05 INFO ResourceUtils: ==============================================================
# 25/11/20 23:18:05 INFO ResourceUtils: No custom resources configured for spark.driver.
# 25/11/20 23:18:05 INFO ResourceUtils: ==============================================================
# 25/11/20 23:18:05 INFO SparkContext: Submitted application: LogErrorMonitor
# 25/11/20 23:18:05 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 25/11/20 23:18:05 INFO ResourceProfile: Limiting resource is cpu
# 25/11/20 23:18:05 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 25/11/20 23:18:05 INFO SecurityManager: Changing view acls to: root
# 25/11/20 23:18:05 INFO SecurityManager: Changing modify acls to: root
# 25/11/20 23:18:05 INFO SecurityManager: Changing view acls groups to:
# 25/11/20 23:18:05 INFO SecurityManager: Changing modify acls groups to:
# 25/11/20 23:18:05 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root; groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY
# 25/11/20 23:18:05 INFO Utils: Successfully started service 'sparkDriver' on port 46037.
# 25/11/20 23:18:05 INFO SparkEnv: Registering MapOutputTracker
# 25/11/20 23:18:05 INFO SparkEnv: Registering BlockManagerMaster
# 25/11/20 23:18:05 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 25/11/20 23:18:05 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 25/11/20 23:18:05 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 25/11/20 23:18:06 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-ffed81a8-c1b9-4f17-82a0-b87d79d97210
# 25/11/20 23:18:06 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 25/11/20 23:18:06 INFO SparkEnv: Registering OutputCommitCoordinator
# 25/11/20 23:18:06 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 25/11/20 23:18:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/11/20 23:18:06 INFO Utils: Successfully started service 'SparkUI' on port 4041.
# 25/11/20 23:18:06 INFO Executor: Starting executor ID driver on host cadd6fbfb210
# 25/11/20 23:18:06 INFO Executor: OS info Linux, 5.15.167.4-microsoft-standard-WSL2, amd64
# 25/11/20 23:18:06 INFO Executor: Java version 17.0.17-internal
# 25/11/20 23:18:06 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 25/11/20 23:18:06 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@2d9913fc for default.
# 25/11/20 23:18:06 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 42633.
# 25/11/20 23:18:06 INFO NettyBlockTransferService: Server created on cadd6fbfb210:42633
# 25/11/20 23:18:06 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 25/11/20 23:18:06 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, cadd6fbfb210, 42633, None)
# 25/11/20 23:18:06 INFO BlockManagerMasterEndpoint: Registering block manager cadd6fbfb210:42633 with 434.4 MiB RAM, BlockManagerId(driver, cadd6fbfb210, 42633, None)
# 25/11/20 23:18:06 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, cadd6fbfb210, 42633, None)
# 25/11/20 23:18:06 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, cadd6fbfb210, 42633, None)
# /opt/conda/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/streaming/context.py:72: FutureWarning: DStream is deprecated as of Spark 3.4.0. Migrate to Structured Streaming.
# 25/11/20 23:18:07 INFO FileInputDStream: Duration for remembering RDDs set to 60000 ms for org.apache.spark.streaming.dstream.FileInputDStream@5c75cb0
# Escuchando logs en: logs
# Solo se mostrarán líneas con ERROR (sin WARNING).
# 25/11/20 23:18:07 INFO FileInputDStream: Slide time = 5000 ms
# 25/11/20 23:18:07 INFO FileInputDStream: Storage level = Serialized 1x Replicated
# 25/11/20 23:18:07 INFO FileInputDStream: Checkpoint interval = null
# 25/11/20 23:18:07 INFO FileInputDStream: Remember interval = 60000 ms
# 25/11/20 23:18:07 INFO FileInputDStream: Initialized and validated org.apache.spark.streaming.dstream.FileInputDStream@5c75cb0
# 25/11/20 23:18:07 INFO MappedDStream: Slide time = 5000 ms
# 25/11/20 23:18:07 INFO MappedDStream: Storage level = Serialized 1x Replicated
# 25/11/20 23:18:07 INFO MappedDStream: Checkpoint interval = null
# 25/11/20 23:18:07 INFO MappedDStream: Remember interval = 5000 ms
# 25/11/20 23:18:07 INFO MappedDStream: Initialized and validated org.apache.spark.streaming.dstream.MappedDStream@5439c97
# 25/11/20 23:18:07 INFO PythonTransformedDStream: Slide time = 5000 ms
# 25/11/20 23:18:07 INFO PythonTransformedDStream: Storage level = Serialized 1x Replicated
# 25/11/20 23:18:07 INFO PythonTransformedDStream: Checkpoint interval = null
# 25/11/20 23:18:07 INFO PythonTransformedDStream: Remember interval = 5000 ms
# 25/11/20 23:18:07 INFO PythonTransformedDStream: Initialized and validated org.apache.spark.streaming.api.python.PythonTransformedDStream@2db2fef
# 25/11/20 23:18:07 INFO ForEachDStream: Slide time = 5000 ms
# 25/11/20 23:18:07 INFO ForEachDStream: Storage level = Serialized 1x Replicated
# 25/11/20 23:18:07 INFO ForEachDStream: Checkpoint interval = null
# 25/11/20 23:18:07 INFO ForEachDStream: Remember interval = 5000 ms
# 25/11/20 23:18:07 INFO ForEachDStream: Initialized and validated org.apache.spark.streaming.dstream.ForEachDStream@3e178dc2
# 25/11/20 23:18:07 INFO RecurringTimer: Started timer for JobGenerator at time 1763680690000
# 25/11/20 23:18:07 INFO JobGenerator: Started JobGenerator at 1763680690000 ms
# 25/11/20 23:18:07 INFO JobScheduler: Started JobScheduler
# 25/11/20 23:18:07 INFO StreamingContext: StreamingContext started
# 25/11/20 23:18:10 INFO FileInputDStream: New files at time 1763680690000 ms:
#
# 25/11/20 23:18:10 INFO JobScheduler: Added jobs for time 1763680690000 ms
# 25/11/20 23:18:10 INFO JobScheduler: Starting job streaming job 1763680690000 ms.0 from job set of time 1763680690000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:10
# -------------------------------------------
#
# 25/11/20 23:18:10 INFO JobScheduler: Finished job streaming job 1763680690000 ms.0 from job set of time 1763680690000 ms
# 25/11/20 23:18:10 INFO JobScheduler: Total delay: 0.252 s for time 1763680690000 ms (execution: 0.007 s)
# 25/11/20 23:18:10 INFO FileInputDStream: Cleared 0 old files that were older than 1763680630000 ms:
# 25/11/20 23:18:10 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:10 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:15 INFO FileInputDStream: New files at time 1763680695000 ms:
#
# 25/11/20 23:18:15 INFO JobScheduler: Added jobs for time 1763680695000 ms
# 25/11/20 23:18:15 INFO JobScheduler: Starting job streaming job 1763680695000 ms.0 from job set of time 1763680695000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:15
# -------------------------------------------
#
# 25/11/20 23:18:15 INFO JobScheduler: Finished job streaming job 1763680695000 ms.0 from job set of time 1763680695000 ms
# 25/11/20 23:18:15 INFO JobScheduler: Total delay: 0.035 s for time 1763680695000 ms (execution: 0.005 s)
# 25/11/20 23:18:15 INFO PythonRDD: Removing RDD 2 from persistence list
# 25/11/20 23:18:15 INFO MapPartitionsRDD: Removing RDD 1 from persistence list
# 25/11/20 23:18:15 INFO FileInputDStream: Cleared 0 old files that were older than 1763680635000 ms:
# 25/11/20 23:18:15 INFO BlockManager: Removing RDD 2
# 25/11/20 23:18:15 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:15 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:15 INFO BlockManager: Removing RDD 1
# 25/11/20 23:18:20 INFO FileInputDStream: New files at time 1763680700000 ms:
#
# 25/11/20 23:18:20 INFO JobScheduler: Added jobs for time 1763680700000 ms
# 25/11/20 23:18:20 INFO JobScheduler: Starting job streaming job 1763680700000 ms.0 from job set of time 1763680700000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:20
# -------------------------------------------
#
# 25/11/20 23:18:20 INFO JobScheduler: Finished job streaming job 1763680700000 ms.0 from job set of time 1763680700000 ms
# 25/11/20 23:18:20 INFO JobScheduler: Total delay: 0.038 s for time 1763680700000 ms (execution: 0.005 s)
# 25/11/20 23:18:20 INFO PythonRDD: Removing RDD 5 from persistence list
# 25/11/20 23:18:20 INFO MapPartitionsRDD: Removing RDD 4 from persistence list
# 25/11/20 23:18:20 INFO BlockManager: Removing RDD 5
# 25/11/20 23:18:20 INFO FileInputDStream: Cleared 0 old files that were older than 1763680640000 ms:
# 25/11/20 23:18:20 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:20 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:20 INFO BlockManager: Removing RDD 4
# 25/11/20 23:18:25 INFO FileInputDStream: New files at time 1763680705000 ms:
#
# 25/11/20 23:18:25 INFO JobScheduler: Added jobs for time 1763680705000 ms
# 25/11/20 23:18:25 INFO JobScheduler: Starting job streaming job 1763680705000 ms.0 from job set of time 1763680705000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:25
# -------------------------------------------
#
# 25/11/20 23:18:25 INFO JobScheduler: Finished job streaming job 1763680705000 ms.0 from job set of time 1763680705000 ms
# 25/11/20 23:18:25 INFO PythonRDD: Removing RDD 8 from persistence list
# 25/11/20 23:18:25 INFO JobScheduler: Total delay: 0.036 s for time 1763680705000 ms (execution: 0.006 s)
# 25/11/20 23:18:25 INFO MapPartitionsRDD: Removing RDD 7 from persistence list
# 25/11/20 23:18:25 INFO BlockManager: Removing RDD 8
# 25/11/20 23:18:25 INFO FileInputDStream: Cleared 0 old files that were older than 1763680645000 ms:
# 25/11/20 23:18:25 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:25 INFO BlockManager: Removing RDD 7
# 25/11/20 23:18:25 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:30 INFO FileInputDStream: New files at time 1763680710000 ms:
#
# 25/11/20 23:18:30 INFO JobScheduler: Added jobs for time 1763680710000 ms
# 25/11/20 23:18:30 INFO JobScheduler: Starting job streaming job 1763680710000 ms.0 from job set of time 1763680710000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:30
# -------------------------------------------
#
# 25/11/20 23:18:30 INFO JobScheduler: Finished job streaming job 1763680710000 ms.0 from job set of time 1763680710000 ms
# 25/11/20 23:18:30 INFO PythonRDD: Removing RDD 11 from persistence list
# 25/11/20 23:18:30 INFO JobScheduler: Total delay: 0.038 s for time 1763680710000 ms (execution: 0.005 s)
# 25/11/20 23:18:30 INFO MapPartitionsRDD: Removing RDD 10 from persistence list
# 25/11/20 23:18:30 INFO BlockManager: Removing RDD 11
# 25/11/20 23:18:30 INFO FileInputDStream: Cleared 0 old files that were older than 1763680650000 ms:
# 25/11/20 23:18:30 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:30 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:30 INFO BlockManager: Removing RDD 10
# 25/11/20 23:18:35 INFO FileInputDStream: New files at time 1763680715000 ms:
#
# 25/11/20 23:18:35 INFO JobScheduler: Starting job streaming job 1763680715000 ms.0 from job set of time 1763680715000 ms
# 25/11/20 23:18:35 INFO JobScheduler: Added jobs for time 1763680715000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:35
# -------------------------------------------
#
# 25/11/20 23:18:35 INFO JobScheduler: Finished job streaming job 1763680715000 ms.0 from job set of time 1763680715000 ms
# 25/11/20 23:18:35 INFO JobScheduler: Total delay: 0.036 s for time 1763680715000 ms (execution: 0.005 s)
# 25/11/20 23:18:35 INFO PythonRDD: Removing RDD 14 from persistence list
# 25/11/20 23:18:35 INFO BlockManager: Removing RDD 14
# 25/11/20 23:18:35 INFO MapPartitionsRDD: Removing RDD 13 from persistence list
# 25/11/20 23:18:35 INFO FileInputDStream: Cleared 0 old files that were older than 1763680655000 ms:
# 25/11/20 23:18:35 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:35 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:35 INFO BlockManager: Removing RDD 13
# 25/11/20 23:18:40 INFO FileInputDStream: New files at time 1763680720000 ms:
#
# 25/11/20 23:18:40 INFO JobScheduler: Added jobs for time 1763680720000 ms
# 25/11/20 23:18:40 INFO JobScheduler: Starting job streaming job 1763680720000 ms.0 from job set of time 1763680720000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:40
# -------------------------------------------
#
# 25/11/20 23:18:40 INFO JobScheduler: Finished job streaming job 1763680720000 ms.0 from job set of time 1763680720000 ms
# 25/11/20 23:18:40 INFO PythonRDD: Removing RDD 17 from persistence list
# 25/11/20 23:18:40 INFO JobScheduler: Total delay: 0.030 s for time 1763680720000 ms (execution: 0.005 s)
# 25/11/20 23:18:40 INFO MapPartitionsRDD: Removing RDD 16 from persistence list
# 25/11/20 23:18:40 INFO BlockManager: Removing RDD 17
# 25/11/20 23:18:40 INFO FileInputDStream: Cleared 0 old files that were older than 1763680660000 ms:
# 25/11/20 23:18:40 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:40 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:40 INFO BlockManager: Removing RDD 16
# 25/11/20 23:18:45 INFO FileInputDStream: New files at time 1763680725000 ms:
#
# 25/11/20 23:18:45 INFO JobScheduler: Added jobs for time 1763680725000 ms
# 25/11/20 23:18:45 INFO JobScheduler: Starting job streaming job 1763680725000 ms.0 from job set of time 1763680725000 ms
# -------------------------------------------
# Time: 2025-11-20 23:18:45
# -------------------------------------------
#
# 25/11/20 23:18:45 INFO JobScheduler: Finished job streaming job 1763680725000 ms.0 from job set of time 1763680725000 ms
# 25/11/20 23:18:45 INFO JobScheduler: Total delay: 0.034 s for time 1763680725000 ms (execution: 0.005 s)
# 25/11/20 23:18:45 INFO PythonRDD: Removing RDD 20 from persistence list
# 25/11/20 23:18:45 INFO MapPartitionsRDD: Removing RDD 19 from persistence list
# 25/11/20 23:18:45 INFO BlockManager: Removing RDD 20
# 25/11/20 23:18:45 INFO FileInputDStream: Cleared 0 old files that were older than 1763680665000 ms:
# 25/11/20 23:18:45 INFO ReceivedBlockTracker: Deleting batches:
# 25/11/20 23:18:45 INFO InputInfoTracker: remove old batch metadata:
# 25/11/20 23:18:45 INFO BlockManager: Removing RDD 19
# ^C
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: reentrant call inside <_io.BufferedReader name=3>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/context.py", line 381, in signal_handler
#     self.cancelAllJobs()
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/context.py", line 2446, in cancelAllJobs
#     self._jsc.sc().cancelAllJobs()
#     ^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#                    ^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o13.sc
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# Traceback (most recent call last):
#   File "/opt/notebooks/261ml/log_streaming.py", line 26, in <module>
# 25/11/20 23:18:48 INFO StreamingContext: Invoking stop(stopGracefully=false) from shutdown hook
# 25/11/20 23:18:48 INFO ReceiverTracker: ReceiverTracker stopped
# 25/11/20 23:18:48 INFO JobGenerator: Stopping JobGenerator immediately
# 25/11/20 23:18:48 INFO RecurringTimer: Stopped timer for JobGenerator after time 1763680725000
#     ssc.awaitTermination()
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/pyspark.zip/pyspark/streaming/context.py", line 239, in awaitTermination
# 25/11/20 23:18:48 INFO JobGenerator: Stopped JobGenerator
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py", line 1322, in __call__
#   File "/opt/conda/lib/python3.11/site-packages/pyspark/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py", line 334, in get_return_value
# py4j.protocol.Py4JError: An error occurred while calling o24.awaitTermination
# 25/11/20 23:18:48 INFO JobScheduler: Stopped JobScheduler
# 25/11/20 23:18:48 INFO StreamingContext: StreamingContext stopped successfully
# 25/11/20 23:18:48 INFO SparkContext: Invoking stop() from shutdown hook
# 25/11/20 23:18:48 INFO SparkContext: SparkContext is stopping with exitCode 0.
# 25/11/20 23:18:48 INFO SparkUI: Stopped Spark web UI at http://cadd6fbfb210:4041
# 25/11/20 23:18:48 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 25/11/20 23:18:48 INFO MemoryStore: MemoryStore cleared
# 25/11/20 23:18:48 INFO BlockManager: BlockManager stopped
# 25/11/20 23:18:48 INFO BlockManagerMaster: BlockManagerMaster stopped
# 25/11/20 23:18:48 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 25/11/20 23:18:48 INFO SparkContext: Successfully stopped SparkContext
# 25/11/20 23:18:48 INFO ShutdownHookManager: Shutdown hook called
# 25/11/20 23:18:48 INFO ShutdownHookManager: Deleting directory /tmp/spark-5510b1b8-5c00-453a-ac8b-ee2749fd51a6/pyspark-16de939e-2126-40e6-9c78-338b0cc7bc6f
# 25/11/20 23:18:48 INFO ShutdownHookManager: Deleting directory /tmp/spark-5510b1b8-5c00-453a-ac8b-ee2749fd51a6
# 25/11/20 23:18:48 INFO ShutdownHookManager: Deleting directory /tmp/spark-d4b97ed3-3548-4403-9b7f-5a08dd29a4c5
